# %%
import pandas as pd

df = pd.read_csv('DataAllMethods_s100.csv', index_col=0)

dfmgType = df[df['microGridType']=='mg1']
for name in df.columns[3:]:
    dfmgType.boxplot(column=name, by='OptMethod')

# %%
dfmgType = df[df['microGridType']=='mg2']
for name in df.columns[3:]:
    dfmgType.boxplot(column=name, by='OptMethod')
